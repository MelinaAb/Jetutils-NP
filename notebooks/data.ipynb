# %% [markdown]
# # Data preprocessing

# %%
import jetutils
from jetutils.jet_finding import JetFindingExperiment, get_double_jet_index, find_all_jets
from jetutils.definitions import DATADIR, get_index_columns, SEASONS, PRETTIER_VARNAME, UNITS, JJADOYS, FIGURES, KAPPA
from jetutils.plots import plot_seasonal, plot_trends, trends_and_pvalues, num2tex, COLORS, periodic_rolling_pl
from jetutils.data import DataHandler, flatten_by, standardize, metadata_from_da, find_spot 
from pathlib import Path
import colormaps

import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.lines import Line2D
import matplotlib.cm as cm
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import xarray as xr
import glob
import os
import seaborn as sns

#%load_ext autoreload
#%autoreload 2
# %matplotlib inline
print(jetutils.__file__)
# Out:
# Found config override file at  /home/mabeling/.jetutils.ini
# Guessed N_WORKERS :  256
# Guessed MEMORY_LIMIT :  8000
# /home/mabeling/Jetutils-NP/jetutils/__init__.py

# %%
# Constants
p0 = 100000  # Pa
KAPPA = 0.286  # R_d / c_p for dry air

# %%
test = xr.open_dataset('/mnt/climstor/ecmwf/era5/raw/PL/data/2021/an_pl_ERA5_2021-06-24.nc')
print(test['level'])
# Out:
# <xarray.DataArray 'level' (level: 17)> Size: 136B
# array([100., 150., 200., 250., 300., 350., 400., 450., 500., 550., 600., 650.,
#        700., 750., 800., 850., 900.])
# Coordinates:
#   * level    (level) float64 136B 100.0 150.0 200.0 250.0 ... 800.0 850.0 900.0
# Attributes:
#     standard_name:  air_pressure
#     long_name:      pressure_level
#     units:          millibars
#     positive:       down
#     axis:           Z

# %%
def process_jet_stream_data(file_pattern, output_dir, output_filename, level_hpa):
    """
    Extracts u, v, t at a given pressure level, computes potential temperature and wind speed,
    and saves the result as a NetCDF file.

    Parameters:
        file_pattern (str): Glob pattern to match input files.
        output_dir (str): Directory to save the output NetCDF.
        output_filename (str): Name of the output file ('uvtths_plev500.nc').
        level_hpa (int): Pressure level in hPa (500).
    """
    p0 = 100000  # Pa
    KAPPA = 0.286  
    
    files = sorted(glob.glob(file_pattern))
    if not files:
        print("No files found matching pattern.")
        return

    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, output_filename)

    print("Loading multiple files...")
    ds = xr.open_mfdataset(files, combine="by_coords")

    try:
        ds = ds.sel(level=level_hpa)
        ds = ds.sel(lat=slice(20, 70)) 
        ds_east = ds.sel(lon=slice(120, 180))
        ds_west = ds.sel(lon=slice(-180, -80))
        ds = xr.concat([ds_east, ds_west], dim="lon")

        required_vars = ['t', 'u', 'v']
        if not all(var in ds.variables for var in required_vars):
            print("Missing required variables: 't', 'u', or 'v'.")
            return

        T = ds['t']
        u = ds['u']
        v = ds['v']
        p = ds['level'] * 100  # Convert hPa to Pa

        _, p_3d = xr.broadcast(T, p)

        # Potential temperature
        theta = T * (p0 / p_3d) ** KAPPA
        theta.name = "theta"

        # Wind speed magnitude
        wind_speed = np.sqrt(u ** 2 + v ** 2)
        wind_speed.name = "s"

        ds_out = xr.merge([T, u, v, theta, wind_speed])

        print("Saving combined file...")
        print("Output dataset dimensions and sizes:")
        for dim in ds_out.dims:
            print(f"  {dim}: {ds_out.dims[dim]}")
        ds_out.to_netcdf(output_path)
        print(f"Saved: {output_path}")

    except Exception as e:
        print(f"Error during processing: {e}")

# %%
def process_files_daily(file_pattern, output_dir, level_hpa):
    files = sorted(glob.glob(file_pattern))
    if not files:
        print("No files found matching the pattern.")
        return

    os.makedirs(output_dir, exist_ok=True)

    for file_path in files:
        print(f"Processing file: {file_path}")
        ds = xr.open_dataset(file_path)

        ds = ds.sel(level=level_hpa)
        ds = ds.sel(lat=slice(20, 70))
        ds_east = ds.sel(lon=slice(120, 180))
        ds_west = ds.sel(lon=slice(-180, -80))
        ds = xr.concat([ds_east, ds_west], dim="lon")

        required_vars = ['t', 'u', 'v']
        if not all(var in ds.variables for var in required_vars):
            print(f"Skipping {file_path}, missing required variables.")
            continue

        for day, ds_day in ds.groupby('time.day'):
            date_str = np.datetime_as_string(ds_day.time.values[0], unit='D')
            print(f"  Processing day: {date_str} ({len(ds_day.time)} time steps)")

            T = ds_day['t']
            u = ds_day['u']
            v = ds_day['v']
            p = ds_day['level'] * 100  # convert hPa to Pa
            _, p_3d = xr.broadcast(T, p)

            theta = T * (p0 / p_3d) ** KAPPA
            theta.name = "theta"
            wind_speed = np.sqrt(u ** 2 + v ** 2)
            wind_speed.name = "s"

            ds_out = xr.merge([T, u, v, theta, wind_speed])

            out_filename = f"uvtths_plev{level_hpa}_{date_str}.nc"
            out_path = os.path.join(output_dir, out_filename)
            ds_out.to_netcdf(out_path)
            print(f"    Saved {out_filename}")

# %%
def process_files_yearly(input_dir, output_dir, level_hpa, level_name, year):
    """
    Processes NetCDF files matching the given pattern and combines all data 
    from the specified year into a single NetCDF file.

    Parameters:
        input_dir (str): Directory where input is stored
        output_dir (str): Directory to save the combined yearly NetCDF.
        level_hpa (int): Pressure level in hPa to extract.
        year (int): Year to filter and process (e.g., 2021).
    """
    p0 = 100000  
    KAPPA = 0.286  
    
    input_dir = f'{input_dir}/{year}'
    file_pattern = os.path.join(input_dir, 'an_pl_ERA5_*.nc')
    files = sorted(glob.glob(file_pattern))
    if not files:
        print("No files found matching the pattern.")
        return

    output_dir = f'{output_dir}/{year}'

    os.makedirs(output_dir, exist_ok=True)
    datasets = []

    for file_path in files:
        print(f"Reading file: {file_path}")
        #ds = xr.open_dataset(file_path)
        with xr.open_dataset(file_path) as ds:

            if not np.any([t.astype('datetime64[Y]').astype(int) + 1970 == year for t in ds.time.values]):
                continue

            ds = ds.sel(level=level_hpa)
            ds = ds.sel(lat=slice(20, 70))

            ds_east = ds.sel(lon=slice(120, 180))
            ds_west = ds.sel(lon=slice(-180, -80))
            ds = xr.concat([ds_east, ds_west], dim="lon")

            if not all(var in ds.variables for var in ['t', 'u', 'v']):
                print(f"Skipping {file_path}, missing required variables.")
                continue

            T = ds['t']
            u = ds['u']
            v = ds['v']
            p = ds['level'] * 100
            _, p_3d = xr.broadcast(T, p)

            theta = T * (p0 / p_3d) ** KAPPA
            theta.name = "theta"
            wind_speed = np.sqrt(u ** 2 + v ** 2)
            wind_speed.name = "s"

            ds_out = xr.merge([T, u, v, theta, wind_speed])
            datasets.append(ds_out)

    if not datasets:
        print("No valid data to save.")
        return

    # Combine all daily datasets into single yearly dataset
    print(f"Combining {len(datasets)} daily datasets for year {year}...")
    yearly_ds = xr.concat(datasets, dim="time")
    yearly_ds = yearly_ds.sortby("time")

    out_filename = f"uvtths_plev{level_name}_{year}.nc"
    out_path = os.path.join(output_dir, out_filename)
    yearly_ds.to_netcdf(out_path)
    print(f"Saved combined yearly file: {out_path}")

# %%
process_files_yearly(
    year=2023,
    input_dir="/mnt/climstor/ecmwf/era5/raw/PL/data",
    output_dir="/scratch2/mabeling/data/ERA5/plev/mid_wind/6H/data",
    level_hpa= slice(500,500), # 150,350
    level_name = 'mid')
# Out:
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-01-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-02-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-03-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-04-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-05-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-06-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-07-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-08-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-09-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-10-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-11-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/2023/an_pl_ERA5_2023-12-31.nc
# Combining 365 daily datasets for year 2023...
# Saved combined yearly file: /scratch2/mabeling/data/ERA5/plev/mid_wind/6H/data/2023/uvtths_plevmid_2023.nc

# %%
#MID
YEARS = range(1990, 1992) 
for year in YEARS:
    process_files_yearly(
        year=year,
        input_dir="/mnt/climstor/ecmwf/era5/raw/PL/data",
        output_dir="/scratch2/mabeling/data/ERA5/plev/mid_wind/6H/data",
        level_hpa= slice(500,500),
        level_name = '500'
    )

# %%
#HIGH
YEARS = range(1997, 1998) 
for year in YEARS:
    process_files_yearly(
        year=year,
        input_dir="/mnt/climstor/ecmwf/era5/raw/PL/data",
        output_dir="/scratch2/mabeling/data/ERA5/plev/high_wind/6H/data",
        level_hpa= slice(150,350),
        level_name = 'high'
    )
# Out:
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-01-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-02-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-03-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-04-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-05-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-06-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-07-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-08-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-09-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-10-31.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-11-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-01.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-02.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-03.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-04.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-05.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-06.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-07.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-08.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-09.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-10.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-11.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-12.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-13.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-14.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-15.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-16.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-17.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-18.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-19.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-20.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-21.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-22.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-23.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-24.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-25.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-26.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-27.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-28.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-29.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-30.nc
# Reading file: /mnt/climstor/ecmwf/era5/raw/PL/data/1997/an_pl_ERA5_1997-12-31.nc
# Combining 365 daily datasets for year 1997...
# Saved combined yearly file: /scratch2/mabeling/data/ERA5/plev/high_wind/6H/data/1997/uvtths_plevhigh_1997.nc

# %%
# process multiple years
# mid level
YEARS = range(2021, 2021) 
input_dir = "/mnt/climstor/ecmwf/era5/raw/PL/data/2021/"
output_dir = "/scratch2/mabeling/data/ERA5/plev/mid_wind/6H/testcase/"
level_hpa = 500

#for year in YEARS:
#    file_pattern = os.path.join(input_dir, f"an_pl_ERA5_{year}*.nc")
#    output_filename = f"uvtths_plev{level_hpa}_{year}.nc"
#    process_jet_stream_data(file_pattern, output_dir, output_filename, slice(500,500))

# %%
def combine_high_wind_datasets(start_year=1959, end_year=2022):
    """
    Combine yearly high wind NetCDF files from 1959 to 2022 into single dataset
    """
    
    high_wind_datasets = []
    for year in range(start_year, end_year + 1):
        print(f"Processing high wind data for year {year}...")
        
        basepath = f"/scratch2/mabeling/data/ERA5/plev/high_wind/6H/data/{year}"
        high_wind_file = f"{basepath}/uvtths_plevhigh_{year}.nc"
        
        if os.path.exists(high_wind_file):
            try:
                ds_high = xr.open_dataset(high_wind_file)
                ds_high = flatten_by(standardize(ds_high), "s")
                high_wind_datasets.append(ds_high)
                print(f"High wind data loaded for {year}")
            except Exception as e:
                print(f"Error loading high wind data for {year}: {e}")
        else:
            print(f"High wind file not found for {year}: {high_wind_file}")
    
    print(f"\nCombining high wind datasets...")
    print(f"High wind datasets found: {len(high_wind_datasets)}")
    
    # Combine datasets along time dimension
    combined_high_wind = None
    
    if high_wind_datasets:
        try:
            combined_high_wind = xr.concat(high_wind_datasets, dim='time', 
                                         coords='minimal', compat='override')
            print("High wind datasets combined successfully")
        except Exception as e:
            print(f"Error combining high wind datasets: {e}")
    
    return combined_high_wind

# %%
ds_high_combine = combine_high_wind_datasets()
# Out:
# Processing high wind data for year 1959...
# [########################################] | 100% Completed | 24.33 s
#   ✓ High wind data loaded for 1959
# Processing high wind data for year 1960...
# [########################################] | 100% Completed | 26.60 s
#   ✓ High wind data loaded for 1960
# Processing high wind data for year 1961...
# [########################################] | 100% Completed | 26.14 s
#   ✓ High wind data loaded for 1961
# Processing high wind data for year 1962...
# [########################################] | 100% Completed | 27.03 s
#   ✓ High wind data loaded for 1962
# Processing high wind data for year 1963...
# [########################################] | 100% Completed | 27.53 s
#   ✓ High wind data loaded for 1963
# Processing high wind data for year 1964...
# [########################################] | 100% Completed | 25.90 s
#   ✓ High wind data loaded for 1964
# Processing high wind data for year 1965...
# [########################################] | 100% Completed | 26.52 s
#   ✓ High wind data loaded for 1965
# Processing high wind data for year 1966...
# [########################################] | 100% Completed | 26.44 s
#   ✓ High wind data loaded for 1966
# Processing high wind data for year 1967...
# [########################################] | 100% Completed | 30.07 s
#   ✓ High wind data loaded for 1967
# Processing high wind data for year 1968...
# [########################################] | 100% Completed | 28.14 s
#   ✓ High wind data loaded for 1968
# Processing high wind data for year 1969...
# [########################################] | 100% Completed | 26.34 s
#   ✓ High wind data loaded for 1969
# Processing high wind data for year 1970...
# [########################################] | 100% Completed | 19.64 s
#   ✓ High wind data loaded for 1970
# Processing high wind data for year 1971...
# [########################################] | 100% Completed | 6.59 ss
#   ✓ High wind data loaded for 1971
# Processing high wind data for year 1972...
# [########################################] | 100% Completed | 5.79 ss
#   ✓ High wind data loaded for 1972
# Processing high wind data for year 1973...
# [########################################] | 100% Completed | 5.98 sms
#   ✓ High wind data loaded for 1973
# Processing high wind data for year 1974...
# [########################################] | 100% Completed | 8.27 sms
#   ✓ High wind data loaded for 1974
# Processing high wind data for year 1975...
# [########################################] | 100% Completed | 15.13 s
#   ✓ High wind data loaded for 1975
# Processing high wind data for year 1976...
# [########################################] | 100% Completed | 13.52 ss
#   ✓ High wind data loaded for 1976
# Processing high wind data for year 1977...
# [########################################] | 100% Completed | 22.10 ss
#   ✓ High wind data loaded for 1977
# Processing high wind data for year 1978...
# [########################################] | 100% Completed | 18.29 s
#   ✓ High wind data loaded for 1978
# Processing high wind data for year 1979...
# [########################################] | 100% Completed | 8.72 ss
#   ✓ High wind data loaded for 1979
# Processing high wind data for year 1980...
# [########################################] | 100% Completed | 8.12 sms
#   ✓ High wind data loaded for 1980
# Processing high wind data for year 1981...
# [########################################] | 100% Completed | 4.18 sms
#   ✓ High wind data loaded for 1981
# Processing high wind data for year 1982...
# [########################################] | 100% Completed | 6.28 sms
#   ✓ High wind data loaded for 1982
# Processing high wind data for year 1983...
# [########################################] | 100% Completed | 5.57 ss
#   ✓ High wind data loaded for 1983
# Processing high wind data for year 1984...
# [########################################] | 100% Completed | 4.66 sms
#   ✓ High wind data loaded for 1984
# Processing high wind data for year 1985...
# [########################################] | 100% Completed | 3.65 sms
#   ✓ High wind data loaded for 1985
# Processing high wind data for year 1986...
# [########################################] | 100% Completed | 4.87 sms
#   ✓ High wind data loaded for 1986
# Processing high wind data for year 1987...
# [########################################] | 100% Completed | 6.11 sms
#   ✓ High wind data loaded for 1987
# Processing high wind data for year 1988...
# [########################################] | 100% Completed | 3.75 sms
#   ✓ High wind data loaded for 1988
# Processing high wind data for year 1989...
# [########################################] | 100% Completed | 4.56 sms
#   ✓ High wind data loaded for 1989
# Processing high wind data for year 1990...
# [########################################] | 100% Completed | 4.28 sms
#   ✓ High wind data loaded for 1990
# Processing high wind data for year 1991...
# [########################################] | 100% Completed | 3.75 sms
#   ✓ High wind data loaded for 1991
# Processing high wind data for year 1992...
# [########################################] | 100% Completed | 5.43 sms
#   ✓ High wind data loaded for 1992
# Processing high wind data for year 1993...
# [########################################] | 100% Completed | 5.05 sms
#   ✓ High wind data loaded for 1993
# Processing high wind data for year 1994...
# [########################################] | 100% Completed | 4.35 sms
#   ✓ High wind data loaded for 1994
# Processing high wind data for year 1995...
# [########################################] | 100% Completed | 4.66 sms
#   ✓ High wind data loaded for 1995
# Processing high wind data for year 1996...
# [########################################] | 100% Completed | 3.84 sms
#   ✓ High wind data loaded for 1996
# Processing high wind data for year 1997...
# [########################################] | 100% Completed | 26.24 s
#   ✓ High wind data loaded for 1997
# Processing high wind data for year 1998...
# [########################################] | 100% Completed | 4.15 sms
#   ✓ High wind data loaded for 1998
# Processing high wind data for year 1999...
# [########################################] | 100% Completed | 3.84 sms
#   ✓ High wind data loaded for 1999
# Processing high wind data for year 2000...
# [########################################] | 100% Completed | 14.14 ss
#   ✓ High wind data loaded for 2000
# Processing high wind data for year 2001...
# [########################################] | 100% Completed | 21.10 ss
#   ✓ High wind data loaded for 2001
# Processing high wind data for year 2002...
# [########################################] | 100% Completed | 16.36 ss
#   ✓ High wind data loaded for 2002
# Processing high wind data for year 2003...
# [########################################] | 100% Completed | 15.86 s
#   ✓ High wind data loaded for 2003
# Processing high wind data for year 2004...
# [########################################] | 100% Completed | 24.60 ss
#   ✓ High wind data loaded for 2004
# Processing high wind data for year 2005...
# [########################################] | 100% Completed | 25.58 s
#   ✓ High wind data loaded for 2005
# Processing high wind data for year 2006...
# [########################################] | 100% Completed | 13.23 ss
#   ✓ High wind data loaded for 2006
# Processing high wind data for year 2007...
# [########################################] | 100% Completed | 5.06 sms
#   ✓ High wind data loaded for 2007
# Processing high wind data for year 2008...
# [########################################] | 100% Completed | 5.39 ss
#   ✓ High wind data loaded for 2008
# Processing high wind data for year 2009...
# [########################################] | 100% Completed | 4.47 sms
#   ✓ High wind data loaded for 2009
# Processing high wind data for year 2010...
# [########################################] | 100% Completed | 7.41 ss
#   ✓ High wind data loaded for 2010
# Processing high wind data for year 2011...
# [########################################] | 100% Completed | 11.42 ss
#   ✓ High wind data loaded for 2011
# Processing high wind data for year 2012...
# [########################################] | 100% Completed | 10.80 ss
#   ✓ High wind data loaded for 2012
# Processing high wind data for year 2013...
# [########################################] | 100% Completed | 9.42 sms
#   ✓ High wind data loaded for 2013
# Processing high wind data for year 2014...
# [########################################] | 100% Completed | 14.57 s
#   ✓ High wind data loaded for 2014
# Processing high wind data for year 2015...
# [########################################] | 100% Completed | 13.67 ss
#   ✓ High wind data loaded for 2015
# Processing high wind data for year 2016...
# [########################################] | 100% Completed | 15.18 s
#   ✓ High wind data loaded for 2016
# Processing high wind data for year 2017...
# [########################################] | 100% Completed | 14.64 s
#   ✓ High wind data loaded for 2017
# Processing high wind data for year 2018...
# [########################################] | 100% Completed | 17.51 s
#   ✓ High wind data loaded for 2018
# Processing high wind data for year 2019...
# [########################################] | 100% Completed | 9.40 ss
#   ✓ High wind data loaded for 2019
# Processing high wind data for year 2020...
# [########################################] | 100% Completed | 9.10 sms
#   ✓ High wind data loaded for 2020
# Processing high wind data for year 2021...
# [########################################] | 100% Completed | 5.97 sms
#   ✓ High wind data loaded for 2021
# Processing high wind data for year 2022...
# [########################################] | 100% Completed | 8.51 sms
#   ✓ High wind data loaded for 2022
#
# Combining high wind datasets...
# High wind datasets found: 64
# ✓ High wind datasets combined successfully

# %%
output_path = "/scratch2/mabeling/data/ERA5/plev/high_wind/6H/data/combined/uvtths_plevhigh_1959_2022.nc"
ds_high_combine.to_netcdf(output_path)

# %%
###
#Z500 Data
###

# %%
def process_z_data_by_year(base_input_dir, output_dir, level_hpa, years=None, lat_bounds=None, lon_bounds=None):
    """
    Extracts z (geopotential height) at a given pressure level and saves yearly NetCDF files.
    
    Parameters:
    base_input_dir (str): Base directory containing year subdirectories.
    output_dir (str): Directory to save the output NetCDF files.
    level_hpa (int): Pressure level in hPa (500).
    years (list, optional): List of years to process. If None, process all year directories found.
    lat_bounds (tuple, optional): (min_lat, max_lat) for latitude slicing. If None, use all available.
    lon_bounds (tuple, optional): (min_lon, max_lon) for longitude slicing. If None, use all available.
    """
    
    os.makedirs(output_dir, exist_ok=True)
    level_name = str(level_hpa)
    
    if years is None:
        years = []
        for item in os.listdir(base_input_dir):
            item_path = os.path.join(base_input_dir, item)
            if os.path.isdir(item_path) and item.isdigit() and len(item) == 4:
                year = int(item)
                if year >= 1959:
                    years.append(year)
        years = sorted(years)
    
    if not years:
        print("No year directories found.")
        return
    
    print(f"Processing data for years: {years}")
    
    for year in years:
        input_dir = f'{base_input_dir}/{year}'
        file_pattern = os.path.join(input_dir, 'an_pl_ERA5_*.nc')
        year_files = sorted(glob.glob(file_pattern))
        
        if not year_files:
            print(f"No files found for year {year} in {input_dir}")
            continue
            
        print(f"\nProcessing year {year} with {len(year_files)} files...")
        
        try:
            datasets = []
            for file in year_files:
                ds = xr.open_dataset(file)
                ds = ds.sel(level=level_hpa)

                if lat_bounds is not None and lon_bounds is not None:
                    min_lat, max_lat = lat_bounds
                    min_lon, max_lon = lon_bounds
                    ds = ds.sel(lat=slice(min_lat, max_lat))
                    ds = ds.sel(lon=slice(min_lon, max_lon))
                else:
                    ds = ds.sel(lat=slice(20, 70))  
                    
                    ds_east = ds.sel(lon=slice(120, 180))
                    ds_west = ds.sel(lon=slice(-180, -80))
                    ds = xr.concat([ds_east, ds_west], dim="lon")
                
                if 'z' not in ds.variables:
                    print(f"Missing required variable 'z' in file: {file}")
                    continue

                z = ds['z'].to_dataset()
                datasets.append(z)
            
            if not datasets:
                print(f"No valid datasets found for year {year}")
                continue
            
            print(f"Combining {len(datasets)} daily datasets for year {year}...")
            yearly_ds = xr.concat(datasets, dim="time")
            yearly_ds = yearly_ds.sortby("time")
            
            year_output_dir = os.path.join(output_dir, str(year))
            os.makedirs(year_output_dir, exist_ok=True)
            
            out_filename = f"z_plev{level_name}_{year}.nc"
            out_path = os.path.join(year_output_dir, out_filename)
            yearly_ds.to_netcdf(out_path)
            print(f"Saved combined yearly file: {out_path}")
            
            print("Output dataset dimensions and sizes:")
            for dim in yearly_ds.dims:
                print(f"  {dim}: {yearly_ds.dims[dim]}")
            
        except Exception as e:
            print(f"Error processing year {year}: {e}")

# %%
def combine_z500_datasets(start_year=1959, end_year=2022):
    """
    Combine z500 NetCDF files from 1959 to 2022 into single dataset
    """
    z500_datasets = []
    
    for year in range(start_year, end_year + 1):
        print(f"Processing z500 data for year {year}...")
        
        basepath = f"/scratch2/mabeling/data/ERA5/plev/high_wind/6H/z500data/{year}"
        z500_file = f"{basepath}/z_plev500_{year}.nc"
        
        if os.path.exists(z500_file):
            try:
                ds_z500 = xr.open_dataset(z500_file)
                z500_datasets.append(ds_z500)
                print(f"z500 data loaded for {year}")
            except Exception as e:
                print(f"Error loading z500 data for {year}: {e}")
        else:
            print(f"Error z500 file not found for {year}: {z500_file}")
    
    print(f"\nCombining z500 datasets...")
    print(f"z500 datasets found: {len(z500_datasets)}")
    combined_z500 = None
    
    if z500_datasets:
        try:
            combined_z500 = xr.concat(z500_datasets, dim='time', 
                                         coords='minimal', compat='override')
            print("z500 datasets combined successfully")
        except Exception as e:
            print(f"Error combining z500 datasets: {e}")
    
    return combined_z500

# %%
ds_z500_combine = combine_z500_datasets()
# Out:
# Processing z500 data for year 1959...
#   ✓ z500 data loaded for 1959
# Processing z500 data for year 1960...
#   ✓ z500 data loaded for 1960
# Processing z500 data for year 1961...
#   ✓ z500 data loaded for 1961
# Processing z500 data for year 1962...
#   ✓ z500 data loaded for 1962
# Processing z500 data for year 1963...
#   ✓ z500 data loaded for 1963
# Processing z500 data for year 1964...
#   ✓ z500 data loaded for 1964
# Processing z500 data for year 1965...
#   ✓ z500 data loaded for 1965
# Processing z500 data for year 1966...
#   ✓ z500 data loaded for 1966
# Processing z500 data for year 1967...
#   ✓ z500 data loaded for 1967
# Processing z500 data for year 1968...
#   ✓ z500 data loaded for 1968
# Processing z500 data for year 1969...
#   ✓ z500 data loaded for 1969
# Processing z500 data for year 1970...
#   ✓ z500 data loaded for 1970
# Processing z500 data for year 1971...
#   ✓ z500 data loaded for 1971
# Processing z500 data for year 1972...
#   ✓ z500 data loaded for 1972
# Processing z500 data for year 1973...
#   ✓ z500 data loaded for 1973
# Processing z500 data for year 1974...
#   ✓ z500 data loaded for 1974
# Processing z500 data for year 1975...
#   ✓ z500 data loaded for 1975
# Processing z500 data for year 1976...
#   ✓ z500 data loaded for 1976
# Processing z500 data for year 1977...
#   ✓ z500 data loaded for 1977
# Processing z500 data for year 1978...
#   ✓ z500 data loaded for 1978
# Processing z500 data for year 1979...
#   ✓ z500 data loaded for 1979
# Processing z500 data for year 1980...
#   ✓ z500 data loaded for 1980
# Processing z500 data for year 1981...
#   ✓ z500 data loaded for 1981
# Processing z500 data for year 1982...
#   ✓ z500 data loaded for 1982
# Processing z500 data for year 1983...
#   ✓ z500 data loaded for 1983
# Processing z500 data for year 1984...
#   ✓ z500 data loaded for 1984
# Processing z500 data for year 1985...
#   ✓ z500 data loaded for 1985
# Processing z500 data for year 1986...
#   ✓ z500 data loaded for 1986
# Processing z500 data for year 1987...
#   ✓ z500 data loaded for 1987
# Processing z500 data for year 1988...
#   ✓ z500 data loaded for 1988
# Processing z500 data for year 1989...
#   ✓ z500 data loaded for 1989
# Processing z500 data for year 1990...
#   ✓ z500 data loaded for 1990
# Processing z500 data for year 1991...
#   ✓ z500 data loaded for 1991
# Processing z500 data for year 1992...
#   ✓ z500 data loaded for 1992
# Processing z500 data for year 1993...
#   ✓ z500 data loaded for 1993
# Processing z500 data for year 1994...
#   ✓ z500 data loaded for 1994
# Processing z500 data for year 1995...
#   ✓ z500 data loaded for 1995
# Processing z500 data for year 1996...
#   ✓ z500 data loaded for 1996
# Processing z500 data for year 1997...
#   ✓ z500 data loaded for 1997
# Processing z500 data for year 1998...
#   ✓ z500 data loaded for 1998
# Processing z500 data for year 1999...
#   ✓ z500 data loaded for 1999
# Processing z500 data for year 2000...
#   ✓ z500 data loaded for 2000
# Processing z500 data for year 2001...
#   ✓ z500 data loaded for 2001
# Processing z500 data for year 2002...
#   ✓ z500 data loaded for 2002
# Processing z500 data for year 2003...
#   ✓ z500 data loaded for 2003
# Processing z500 data for year 2004...
#   ✓ z500 data loaded for 2004
# Processing z500 data for year 2005...
#   ✓ z500 data loaded for 2005
# Processing z500 data for year 2006...
#   ✓ z500 data loaded for 2006
# Processing z500 data for year 2007...
#   ✓ z500 data loaded for 2007
# Processing z500 data for year 2008...
#   ✓ z500 data loaded for 2008
# Processing z500 data for year 2009...
#   ✓ z500 data loaded for 2009
# Processing z500 data for year 2010...
#   ✓ z500 data loaded for 2010
# Processing z500 data for year 2011...
#   ✓ z500 data loaded for 2011
# Processing z500 data for year 2012...
#   ✓ z500 data loaded for 2012
# Processing z500 data for year 2013...
#   ✓ z500 data loaded for 2013
# Processing z500 data for year 2014...
#   ✓ z500 data loaded for 2014
# Processing z500 data for year 2015...
#   ✓ z500 data loaded for 2015
# Processing z500 data for year 2016...
#   ✓ z500 data loaded for 2016
# Processing z500 data for year 2017...
#   ✓ z500 data loaded for 2017
# Processing z500 data for year 2018...
#   ✓ z500 data loaded for 2018
# Processing z500 data for year 2019...
#   ✓ z500 data loaded for 2019
# Processing z500 data for year 2020...
#   ✓ z500 data loaded for 2020
# Processing z500 data for year 2021...
#   ✓ z500 data loaded for 2021
# Processing z500 data for year 2022...
#   ✓ z500 data loaded for 2022
#
# Combining z500 datasets...
# z500 datasets found: 64
# ✓ z500 datasets combined successfully

# %%
output_path = "/scratch2/mabeling/data/ERA5/plev/high_wind/6H/z500data/combined/z500_1959_2022.nc"
ds_z500_combine.to_netcdf(output_path)

# %%
ds = xr.open_dataset("/scratch2/mabeling/data/ERA5/plev/high_wind/6H/z500data/2017/z_plev500_2017.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 379MB
# Dimensions:  (time: 1460, lat: 101, lon: 321)
# Coordinates:
#   * time     (time) datetime64[ns] 12kB 2017-01-01 ... 2017-12-31T18:00:00
#   * lon      (lon) float32 1kB 120.0 120.5 121.0 121.5 ... -81.0 -80.5 -80.0
#   * lat      (lat) float32 404B 20.0 20.5 21.0 21.5 22.0 ... 68.5 69.0 69.5 70.0
#     level    float64 8B ...
# Data variables:
#     z        (time, lat, lon) float64 379MB ...

# %%
process_z_data_by_year(
     base_input_dir="/mnt/climstor/ecmwf/era5/raw/PL/data", 
     output_dir="/scratch2/mabeling/data/ERA5/plev/high_wind/6H/z500data",
     level_hpa=500,
     years=None  # Optional: specify years, None = all
)

# %%
def combine_mid_wind_datasets(start_year=2000, end_year=2023):
    """
    Combine yearly mid wind NetCDF files from 2000 to 2023 into single dataset
    """
    
    # List to store mid wind datasets
    mid_wind_datasets = []
    
    # Loop through all years
    for year in range(start_year, end_year + 1):
        print(f"Processing mid wind data for year {year}...")
        
        # Define path for current year
        basepath_mid = f"/scratch2/mabeling/data/ERA5/plev/mid_wind/6H/data/{year}"
        mid_wind_file = f"{basepath_mid}/uvtths_plev500_{year}.nc"
        
        # Check if file exists before trying to open it
        if os.path.exists(mid_wind_file):
            try:
                # Load and process mid wind data
                ds_mid = xr.open_dataset(mid_wind_file)
                ds_mid = flatten_by(standardize(ds_mid), "s")
                mid_wind_datasets.append(ds_mid)
                print(f"Mid wind data loaded for {year}")
            except Exception as e:
                print(f"Error loading mid wind data for {year}: {e}")
        else:
            print(f"Mid wind file not found for {year}: {mid_wind_file}")
    
    print(f"\nCombining mid wind datasets...")
    print(f"Mid wind datasets found: {len(mid_wind_datasets)}")
    
    combined_mid_wind = None
    
    if mid_wind_datasets:
        try:
            combined_mid_wind = xr.concat(mid_wind_datasets, dim='time', 
                                        coords='minimal', compat='override')
            print("Mid wind datasets combined successfully")
        except Exception as e:
            print(f"Error combining mid wind datasets: {e}")
    
    return combined_mid_wind
